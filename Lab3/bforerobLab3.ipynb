# %% [markdown]
# **Python for Data Science**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Data analisys with python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Data Visualization with Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# LinkedIn Profile: https://www.linkedin.com/in/brandon-forero-briceño-179b42268/

# %% [markdown]
# ![image.png](data:image/png;base64,...)
